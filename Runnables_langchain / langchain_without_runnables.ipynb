# %% [markdown]
# <a href="https://colab.research.google.com/github/jonash-chataut/GenAI/blob/main/Runnables_langchain%20/%20langchain_without_runnables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

class FakeLLM:

  def __init__(self):
    print('LLM created')

  def predict(self, prompt):

    response_list = [
        'LMM predicts this',
        'LLM predicts that',
        'How LLM works',
        'AI stands for Artificial Intelligence'
    ]

    return {'response': random.choice(response_list)}

# %%
class FakePromptTemplate:

  def __init__(self, template, input_variables):
    self.template = template
    self.input_variables = input_variables

  def format(self, input_dict):
    return self.template.format(**input_dict)

# %%
template = FakePromptTemplate(
    template='Write a {length} poem about {topic}',
    input_variables=['length', 'topic']
)

# %%
prompt = template.format({'length':'short','topic':'india'})

# %%
llm = FakeLLM()
# Out:
# LLM created

# %%
llm.predict(prompt)
# Out:
# {'response': 'LLM predicts that'}

# %%
class FakeLLMChain:

  def __init__(self, llm, prompt):
    self.llm = llm
    self.prompt = prompt

  def run(self, input_dict):

    final_prompt = self.prompt.format(input_dict)
    result = self.llm.predict(final_prompt)

    return result['response']

# %%
template = FakePromptTemplate(
    template='Write a {length} poem about {topic}',
    input_variables=['length', 'topic']
)

# %%
llm = FakeLLM()
# Out:
# LLM created

# %%
chain = FakeLLMChain(llm, template)

# %%
chain.run({'length':'short', 'topic': 'LLM'})
# Out:
# 'AI stands for Artificial Intelligence'
